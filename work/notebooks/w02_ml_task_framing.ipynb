# %% [markdown]
# <a href="https://colab.research.google.com/github/usman-nadeembajwa/Doordash/blob/main/work/notebooks/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
# My Lane: predicting how well a piece of contract will perform in search.
# This is a SCORING problem - performance is a spectrum, not yes/no.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
# Target proxy: current search ranking position for the contents keyword.
# This is the proxy for real traffic (which takes weeks to materialise).
# and its an observed outcome, not a rule i invented.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
# Success metric: Mean Absolute Error (MAE) between predicted and actual ranking.
#A model is a "good" if its MAE beats a naive baseline.
#Always predicting the average performance by at least 20%.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
# !git clone https://github.com/usman-nadeembajwa/Doordash.git
import os
print(os.listdir("Doordash/data/raw"))
# Out:
# Cloning into 'Doordash'...
# remote: Enumerating objects: 104, done.
# remote: Counting objects: 100% (104/104), done.
# remote: Compressing objects: 100% (75/75), done.
# remote: Total 104 (delta 24), reused 79 (delta 13), pack-reused 0 (from 0)
# Receiving objects: 100% (104/104), 1.81 MiB | 8.06 MiB/s, done.
# Resolving deltas: 100% (24/24), done.
# ['content_refresh_anonymized.csv']

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
# The program lets if stament to let the value of 0 or 1

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
