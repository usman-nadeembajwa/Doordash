# %% [markdown]
# # ML-08 — Capstone Modeling Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Method choice and why
#
# *Which method from the toolkit, and why it fits your lane.*

# %%
# am using logistic Regression (multi- class) to predict the action category (growing/declining/recovering/worth_review) from GSC signals (impressions, clicks, positions, and their trend over the month) I choose the over random
#forest because interpredability matters here- the content team needs to understand *why* apage was flagged, not just get a black boxc label

# %% [markdown]
# ## 2. Split design
#
# *Grouped by client? Time-aware? Say why this split is honest for your question.*

# %%
#group by content_has_id,not random row solit!
#Same content shouldnt appear in both train and tewst- thats leakage
#from sklearn.model_sel;ection import GroupShuffleSplit
#gss=GroupShuffleSplit(n_splits=1,testsize=0.2, random_state=42)
#train_idx,test_idx=next(gss.split(dfgroups=df['content_hash_Id']))
#train_df, test_df=df.iloc[train_idx],df.iloc[test_idx]

# %% [markdown]
# ## 3. Train + compare vs my baseline
#
# *Same data, same metric, same split as your Week-4 baseline. Show the table.*

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
features = ['gsc_impressions', 'gsc_clicks', 'gsc_avg_position']

X_train, y_train = train_df[features], train_df['action_label']
X_test, y_test = test_df[features], test_df['action_label']

model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)

preds = model.predict(X_test)

print("Model accuracy:", accuracy_score(y_test, preds))
print(classification_report(y_test, preds))
# Compare against your Week-4 baseline_action_score.csv predictions on the same test rows
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_912/1234667963.py in <cell line: 0>()
#       3 features = ['gsc_impressions', 'gsc_clicks', 'gsc_avg_position']
#       4
# ----> 5 X_train, y_train = train_df[features], train_df['action_label']
#       6 X_test, y_test = test_df[features], test_df['action_label']
#       7
#
# NameError: name 'train_df' is not defined

# %% [markdown]
# ## 4. Errors and interpretation
#
# *Where is the model wrong? What does it lean on? A short error analysis beats a big metric table.*

# %%
import pandas as pd
import md as model

coef_df=pd.DataFrame(model.coef_,columns=features, index=model.classes_)
print (coef_df)
#shows which features push towards which label
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_912/634471623.py in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 import md as model
#       3
#       4 coef_df=pd.DataFrame(model.coef_,columns=features, index=model.classes_)
#       5 print (coef_df)
#
# ModuleNotFoundError: No module named 'md'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
